# %% [markdown]
# # **Statistics Part 2**
#
# ---

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#     - Hypothesis testing is a method used in statistics to make decisions or inferences about population parameters based on sample data. Basically, we test an assumption (hypothesis) to see if it's likely to be true or not.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#     - The null hypothesis (H₀) is the default assumption that there's no effect or no difference. The alternative hypothesis (H₁) is what we want to prove — it states that there is an effect or a difference. We test the null hypothesis, and if the data strongly goes against it, we reject it in favor of the alternative.
#
# 3. What is the significance level in hypothesis testing, and why is it important?
#     - The significance level (usually written as α) is the threshold we set to decide whether to reject the null hypothesis. Common values are 0.05 or 0.01. It's important because it controls the chance of making a Type 1 error — rejecting the null hypothesis when it's actually true.
#
# 4. What does a P-value represent in hypothesis testing?
#     - The P-value shows the probability of getting a result as extreme as the one observed (or more) if the null hypothesis is true. It helps us decide whether to reject the null hypothesis.
#
# 5. How do you interpret the P-value in hypothesis testing?
#     - If the P-value is less than the significance level (like 0.05), we reject the null hypothesis — it means the result is statistically significant. If it's greater, we fail to reject the null — meaning we don’t have enough evidence to say there’s a real effect.
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#     - A Type 1 error happens when we reject a true null hypothesis (false positive), and a Type 2 error happens when we fail to reject a false null hypothesis (false negative). Type 1 is like thinking there's an effect when there isn’t, and Type 2 is missing an effect when there actually is one.
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#     - A one-tailed test checks for an effect in just one direction (greater than or less than), while a two-tailed test checks for any difference — either higher or lower. Two-tailed is more common when we don’t know the direction of the effect in advance.
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
#     - The Z-test is used to test hypotheses about population means when the population standard deviation is known and the sample size is large. It's based on the normal distribution.
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#     - The Z-score is calculated as:
# 𝑍
# =
# (
# 𝑋
# −
# 𝜇
# )
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#  (X−μ)
# ​
#     - It shows how many standard deviations the sample mean is from the population mean. It helps us determine the probability of observing a value if the null hypothesis is true.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#     - The T-distribution is similar to the normal distribution but has heavier tails. We use it when the sample size is small (typically n < 30) and the population standard deviation is unknown. It helps account for the extra uncertainty in small samples.
#
# 11. What is the difference between a Z-test and a T-test?
#     - The main difference is that a Z-test is used when the population standard deviation is known and the sample size is large, while a T-test is used when the population standard deviation is unknown and the sample size is small. Z-test uses the normal distribution; T-test uses the t-distribution.
#
# 12. What is the T-test, and how is it used in hypothesis testing?
#     - A T-test is used to compare the means of two groups and see if they are significantly different from each other. It’s especially useful when the sample size is small and the population standard deviation isn’t known.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#     - Both are used to test hypotheses about means. The Z-test is basically a special case of the T-test used when we have more information (like a known population standard deviation). As sample size increases, the T-distribution becomes more like the Z-distribution.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#     - A confidence interval gives a range within which we expect the true population parameter to lie, with a certain level of confidence (like 95%). It helps us understand how precise our estimate is.
#
# 15. What is the margin of error, and how does it affect the confidence interval?
#     - The margin of error is the amount we add and subtract from the sample statistic to create the confidence interval. A larger margin of error means a wider interval, which shows less precision.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#     - Bayes' Theorem is used to update the probability of a hypothesis based on new evidence. It’s important in situations where we want to revise beliefs as more data becomes available, like in medical testing or spam filtering.
#
# 17. What is the Chi-square distribution, and when is it used?
#     - The Chi-square distribution is used in tests involving categorical data, especially for testing independence or goodness of fit. It’s skewed to the right and depends on degrees of freedom.
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#     - The Chi-square goodness of fit test checks if the observed frequencies match the expected frequencies for a single categorical variable. It helps us see if our data fits a particular distribution.
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#     - The F-distribution is used when comparing two variances or in ANOVA. It’s right-skewed and depends on two sets of degrees of freedom. It’s mainly used to test if multiple group means are equal.
#
# 20. What is an ANOVA test, and what are its assumptions?
#     - ANOVA (Analysis of Variance) is used to compare the means of three or more groups. Its assumptions are: independence of observations, normality of the groups, and equal variances (homogeneity of variance).
#
# 21. What are the different types of ANOVA tests?
#     - There are mainly three types:
#     - One-way ANOVA: compares means of three or more groups based on one factor.
#     - Two-way ANOVA: involves two factors and checks interaction between them.
#     - Repeated Measures ANOVA: used when the same subjects are measured multiple times.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
#     - The F-test compares two variances to check if they are significantly different. It's the basis for ANOVA and helps test if group means differ by looking at variance between and within groups.

# %% [markdown]
# # **Practical Part - 1**
#
# ---

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value?

# %%
import random

value = random.random()
print("Random variable:", value)
# Out:
# Random variable: 0.1670742533279631

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)

# Check Matplotlib version and use appropriate stem function call
import matplotlib
if matplotlib.__version__ >= '3.3':
    plt.stem(x, pmf, use_line_collection=True)  # Use use_line_collection for Matplotlib 3.3+
else:
    plt.stem(x, pmf)  # For older versions, omit use_line_collection

plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Values")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution?

# %%
from scipy.stats import bernoulli

def bernoulli_pdf(p):
    x = [0, 1]
    probs = bernoulli.pmf(x, p)
    return dict(zip(x, probs))

print(bernoulli_pdf(0.6))
# Out:
# {0: np.float64(0.4000000000000001), 1: np.float64(0.6)}

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram?

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.binomial(n=10, p=0.5, size=1000)

plt.hist(data, bins=range(12), edgecolor='black')
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python?

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 15)
pmf = poisson.pmf(x, mu=4)

# Check Matplotlib version and use appropriate stem function call
import matplotlib
if matplotlib.__version__ >= '3.3':
    plt.stem(x, pmf, use_line_collection=True)  # Use use_line_collection for Matplotlib 3.3+
else:
    plt.stem(x, pmf)  # For older versions, omit use_line_collection


plt.title("Poisson Distribution (λ=4)")
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution?

# %%
from scipy.stats import randint
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 7)
cdf = randint.cdf(x, 1, 7)

plt.step(x, cdf, where='post')
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Values")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it?

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.uniform(low=0, high=1, size=1000)

plt.hist(data, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram?

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(data, bins=30, edgecolor='black', density=True)
plt.title("Normal Distribution (mean=0, std=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

def plot_z_scores(data):
    z_scores = zscore(data)
    plt.plot(z_scores, marker='o', linestyle='none')
    plt.title("Z-scores of Dataset")
    plt.xlabel("Index")
    plt.ylabel("Z-score")
    plt.grid(True)
    plt.show()

data = np.random.normal(50, 10, 100)
plot_z_scores(data)

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.random.exponential(scale=2.0, size=10000)

sample_means = []
for _ in range(1000):
    sample = np.random.choice(population, size=30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title("Central Limit Theorem - Sampling Distribution")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem?

# %%
import numpy as np
import matplotlib.pyplot as plt

means = []
for _ in range(1000):
    sample = np.random.normal(loc=10, scale=5, size=30)
    means.append(np.mean(sample))

plt.hist(means, bins=30, density=True, edgecolor='black')
plt.title("CLT Verification - Sampling Means Histogram")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)?

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, 0, 1)

plt.plot(x, pdf)
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.xlabel("x")
plt.ylabel("PDF")
plt.grid(True)
plt.show()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution?

# %%
from scipy.stats import binom

n, p = 10, 0.5
x = range(11)
probs = binom.pmf(x, n, p)

for i, prob in zip(x, probs):
    print(f"P(X={i}) = {prob}")
# Out:
# P(X=0) = 0.0009765624999999989
# P(X=1) = 0.009765625000000002
# P(X=2) = 0.04394531250000004
# P(X=3) = 0.1171875
# P(X=4) = 0.2050781249999999
# P(X=5) = 0.24609375000000003
# P(X=6) = 0.2050781249999999
# P(X=7) = 0.11718749999999999
# P(X=8) = 0.04394531250000004
# P(X=9) = 0.009765625000000002
# P(X=10) = 0.0009765625

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution?

# %%
from scipy.stats import norm

value = 75
mean = 70
std_dev = 5
z_score = (value - mean) / std_dev

prob = norm.cdf(z_score)
print("Z-score:", z_score)
print("P-value (from standard normal):", prob)
# Out:
# Z-score: 1.0
# P-value (from standard normal): 0.8413447460685429

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset?

# %%
from scipy.stats import norm

sample_mean = 52
population_mean = 50
std_dev = 4
n = 30

z = (sample_mean - population_mean) / (std_dev / (n**0.5))
p_value = 1 - norm.cdf(z)

print("Z-statistic:", z)
print("P-value:", p_value)
# Out:
# Z-statistic: 2.7386127875258306
# P-value: 0.0030849496602720627

# %% [markdown]
# 16. Create a confidence interval for a dataset using Python and interpret the result?

# %%
import numpy as np
from scipy.stats import norm

data = np.random.normal(100, 15, 50)
mean = np.mean(data)
std_err = np.std(data, ddof=1) / np.sqrt(len(data))

ci = norm.interval(0.95, loc=mean, scale=std_err)
print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (np.float64(99.02937585081266), np.float64(107.35734436064031))

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean?

# %%
import numpy as np
from scipy.stats import norm

data = np.random.normal(75, 10, 100)
mean = np.mean(data)
sem = np.std(data, ddof=1) / np.sqrt(len(data))

conf_int = norm.interval(0.95, loc=mean, scale=sem)
print("Mean:", mean)
print("95% Confidence Interval:", conf_int)
# Out:
# Mean: 75.04242608400382
# 95% Confidence Interval: (np.float64(72.96475892843748), np.float64(77.12009323957017))

# %% [markdown]
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution?

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(50, 100, 1000)
pdf = norm.pdf(x, loc=75, scale=10)

plt.plot(x, pdf)
plt.title("PDF of Normal Distribution")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution?

# %%
from scipy.stats import poisson

x = 3
mu = 4
cdf_value = poisson.cdf(x, mu)
print(f"CDF of Poisson(μ={mu}) at x={x} is {cdf_value}")
# Out:
# CDF of Poisson(μ=4) at x=3 is 0.43347012036670896

# %% [markdown]
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value?

# %%
import numpy as np

data = np.random.uniform(0, 10, 1000)
expected_value = np.mean(data)
print("Expected Value (mean):", expected_value)
# Out:
# Expected Value (mean): 4.886326300653198

# %% [markdown]
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference?

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(50, 5, 1000)
data2 = np.random.normal(50, 10, 1000)

print("STD of dataset 1:", np.std(data1))
print("STD of dataset 2:", np.std(data2))

plt.hist(data1, bins=30, alpha=0.5, label='STD=5')
plt.hist(data2, bins=30, alpha=0.5, label='STD=10')
plt.legend()
plt.title("Comparison of Standard Deviations")
plt.show()
# Out:
# STD of dataset 1: 4.999740057786738
# STD of dataset 2: 9.926837637968687

# %% [markdown]
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution?

# %%
import numpy as np

data = np.random.normal(100, 15, 1000)

data_range = np.max(data) - np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print("Range:", data_range)
print("Interquartile Range (IQR):", iqr)
# Out:
# Range: 116.68874185414786
# Interquartile Range (IQR): 19.8061902589061

# %% [markdown]
# 23. Implement Z-score normalization on a dataset and visualize its transformation?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

data = np.random.normal(100, 20, 100)
normalized = zscore(data)

plt.hist(data, bins=20, alpha=0.5, label='Original')
plt.hist(normalized, bins=20, alpha=0.5, label='Z-score Normalized')
plt.legend()
plt.title("Z-score Normalization")
plt.show()

# %% [markdown]
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution?

# %%
import numpy as np
from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)

print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.11149312311938647
# Kurtosis: 0.09948590207343022

# %% [markdown]
# # **Practical Part - 2**
#
# ---

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results?

# %%
from scipy.stats import norm
import numpy as np

sample = [52, 50, 51, 53, 52, 50, 49, 54, 52, 51]
sample_mean = np.mean(sample)
population_mean = 50
std_dev = 2  # population standard deviation
n = len(sample)

z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print("Z-score:", z)
print("P-value:", p_value)

if p_value < 0.05:
    print("Reject null hypothesis.")
else:
    print("Fail to reject null hypothesis.")
# Out:
# Z-score: 2.2135943621178633
# P-value: 0.026856695507524675
# Reject null hypothesis.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?

# %%
import numpy as np
from scipy.stats import ttest_1samp

data = np.random.normal(55, 5, 30)
t_stat, p_value = ttest_1samp(data, popmean=50)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 7.684983730562279
# P-value: 1.7891749011224594e-08

# %% [markdown]
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean?

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(data, pop_mean, pop_std):
    sample_mean = np.mean(data)
    n = len(data)
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p = 2 * (1 - norm.cdf(abs(z)))
    return z, p

sample = np.random.normal(102, 10, 40)
z_score, p_value = one_sample_z_test(sample, 100, 10)
print("Z-score:", z_score)
print("P-value:", p_value)
# Out:
# Z-score: 1.7067431641337665
# P-value: 0.08786980055790217

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

sample_mean = 52
population_mean = 50
std_dev = 4
n = 30

z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
alpha = 0.05

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y)
plt.fill_between(x, y, where=(x < norm.ppf(alpha/2)) | (x > norm.ppf(1 - alpha/2)), color='red', alpha=0.3)
plt.axvline(z, color='blue', linestyle='--', label=f'Z = {z:.2f}')
plt.legend()
plt.title("Two-Tailed Z-Test Decision Region")
plt.show()

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 0.05
beta = 0.2
mean_null = 0
mean_alt = 1
std = 1

x = np.linspace(-4, 4, 1000)
null_dist = norm.pdf(x, mean_null, std)
alt_dist = norm.pdf(x, mean_alt, std)

z_crit = norm.ppf(1 - alpha)

plt.plot(x, null_dist, label="Null Hypothesis")
plt.plot(x, alt_dist, label="Alternative Hypothesis")
plt.fill_between(x, null_dist, where=(x > z_crit), color='red', alpha=0.3, label="Type I Error")
plt.fill_between(x, alt_dist, where=(x < z_crit), color='blue', alpha=0.3, label="Type II Error")
plt.legend()
plt.title("Type I and Type II Errors")
plt.show()

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results?

# %%
from scipy.stats import ttest_ind
import numpy as np

group1 = np.random.normal(50, 5, 30)
group2 = np.random.normal(53, 5, 30)

t_stat, p_value = ttest_ind(group1, group2)
print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -1.9478965174945218
# P-value: 0.056272516190436606

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results?

# %%
import numpy as np
from scipy.stats import ttest_rel
import matplotlib.pyplot as plt

before = np.random.normal(70, 5, 20)
after = before + np.random.normal(2, 3, 20)

t_stat, p_value = ttest_rel(before, after)
print("T-statistic:", t_stat)
print("P-value:", p_value)

plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.legend()
plt.title("Paired Sample T-test")
plt.show()
# Out:
# T-statistic: -2.254158289389588
# P-value: 0.03618602389693278

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python?

# %%
import numpy as np
from scipy.stats import ttest_1samp, norm

data = np.random.normal(100, 15, 25)

# Z-test
pop_mean = 100
pop_std = 15
z = (np.mean(data) - pop_mean) / (pop_std / np.sqrt(len(data)))
p_z = 2 * (1 - norm.cdf(abs(z)))

# T-test
t_stat, p_t = ttest_1samp(data, pop_mean)

print("Z-test P-value:", p_z)
print("T-test P-value:", p_t)
# Out:
# Z-test P-value: 0.8680146281933994
# T-test P-value: 0.8558434096640141

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance?

# %%
from scipy.stats import norm
import numpy as np

def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    se = np.std(data, ddof=1) / np.sqrt(len(data))
    margin = norm.ppf((1 + confidence) / 2) * se
    return (mean - margin, mean + margin)

data = np.random.normal(100, 10, 40)
ci = confidence_interval(data)
print("Confidence Interval:", ci)
# Out:
# Confidence Interval: (np.float64(96.62171853518466), np.float64(102.9000737558825))

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data?

# %%
from scipy.stats import norm
import numpy as np

data = np.random.normal(75, 12, 50)
confidence = 0.95

se = np.std(data, ddof=1) / np.sqrt(len(data))
z = norm.ppf((1 + confidence) / 2)
margin = z * se

print("Margin of Error:", margin)
# Out:
# Margin of Error: 2.717783842890925

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process?

# %%
def bayes_theorem(prior_A, likelihood_B_given_A, prior_not_A, likelihood_B_given_not_A):
    numerator = likelihood_B_given_A * prior_A
    denominator = numerator + (likelihood_B_given_not_A * prior_not_A)
    posterior_A_given_B = numerator / denominator
    return posterior_A_given_B

# Example:
# Disease test example: P(Disease) = 0.01, P(Positive|Disease) = 0.99, P(Positive|No Disease) = 0.05
posterior = bayes_theorem(0.01, 0.99, 0.99, 0.05)
print(f"Posterior Probability of Disease given Positive Test: {posterior:.4f}")
# Out:
# Posterior Probability of Disease given Positive Test: 0.1667

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python?

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Sample contingency table
data = [[30, 10], [20, 40]]
table = pd.DataFrame(data, columns=['Like', 'Dislike'], index=['Male', 'Female'])

chi2, p, dof, expected = chi2_contingency(table)
print(f"Chi-square Statistic: {chi2:.2f}")
print(f"P-value: {p:.4f}")
# Out:
# Chi-square Statistic: 15.04
# P-value: 0.0001

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data?

# %%
import numpy as np

observed = np.array([[30, 10], [20, 40]])
row_totals = observed.sum(axis=1, keepdims=True)
col_totals = observed.sum(axis=0, keepdims=True)
grand_total = observed.sum()

expected = row_totals @ col_totals / grand_total
print("Expected Frequencies:\n", expected)
# Out:
# Expected Frequencies:
#  [[20. 20.]
#  [30. 30.]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution?

# %%
from scipy.stats import chisquare

observed = [50, 30, 20]
expected = [40, 40, 20]

chi2_stat, p_val = chisquare(f_obs=observed, f_exp=expected)
print(f"Chi-square Stat: {chi2_stat:.2f}, P-value: {p_val:.4f}")
# Out:
# Chi-square Stat: 5.00, P-value: 0.0821
